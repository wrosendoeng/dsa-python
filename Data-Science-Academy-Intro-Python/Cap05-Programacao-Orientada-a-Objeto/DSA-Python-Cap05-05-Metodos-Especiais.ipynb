# %%
class Livro():
    
    def __init__(self,titulo,autor,paginas):
        print("Livro criado")
        self.titulo = titulo
        self.autor = autor
        self.paginas = paginas
        
    def __str__(self):
        return "Titulo: %s, autor: %s, páginas: %s " \
    %(self.titulo, self.autor, self.paginas)
    
    def __len__(self):
        return self.paginas
    
    def len(self):
        return print("Páginas do livro com método comum: ", self.paginas)

# %%
livro1 = Livro("Os Lusíadas", "Luís de Camões", 8816)
# Out:
# Livro criado

# %%
print(livro1)
# Out:
# Titulo: Os Lusíadas, autor: Luís de Camões, páginas: 8816

# %%
str(livro1)
# Out:
# 'Titulo: Os Lusíadas, autor: Luís de Camões, páginas: 8816 '

# %%
len(livro1)
# Out:
# 8816

# %%
livro1.len()
# Out:
# Páginas do livro com método comum:  8816

# %%
del livro1.paginas

# %%
hasattr(livro1,paginas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f2544d8b72f8> in <module>
# ----> 1 hasattr(livro1,paginas)
#
# NameError: name 'paginas' is not defined

# %% [markdown]
# ## Fim
