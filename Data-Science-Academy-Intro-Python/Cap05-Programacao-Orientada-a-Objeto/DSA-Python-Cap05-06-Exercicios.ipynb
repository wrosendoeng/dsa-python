# %%
# Exercício 1 - Crie um objeto a partir da classe abaixo, chamado roc1, passando 2 parâmetros e depois faça uma chamada
# aos atributos e métodos

from math import sqrt

class Rocket():
    
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y
    
    def move_rocket(self, x_increment=0, y_increment=0):
        self.x += x_increment
        self.y += y_increment
        
    def print_rocket(self):
        print(self.x, self.y)
        
roc1 = Rocket(x=5, y=5)

# %%
roc1.move_rocket(x_increment=5,y_increment=12)

# %%
roc1.print_rocket()
# Out:
# 10 17

# %%
# Exercício 2 - Crie uma classe chamada Pessoa() com os atributos: nome, cidade, telefone e e-mail. Use pelo menos 2
# métodos especiais na sua classe. Crie um objeto da sua classe e faça uma chamada a pelo menos um dos seus métodos
# especiais.

class Pessoa():
    
    def __init__(self, nome, cidade, telefone, email):
        self.nome = nome
        self.cidade = cidade
        self.telefone = telefone
        self.email = email
        
    def __str__(self):
        return "Nome: %s, cidade: %s, telefone: %s, e-mail: %s" \
    %(self.nome,self.cidade,str(self.telefone),self.email)
    
    def __len__(self):
        return self.telefone
    
    def len(self):
        print("Entrar em contato pelo WhatsApp através do número: ", self.telefone)

# %%
pessoa1 = Pessoa("Jose","Recife",12349786,"jose.carvalho@email.com")

# %%
str(pessoa1)
# Out:
# 'Nome: Jose, cidade: Recife, telefone: 12349786, e-mail: jose.carvalho@email.com'

# %%
len(pessoa1)
# Out:
# 12349786

# %%
pessoa1.len()
# Out:
# Entrar em contato pelo WhatsApp através do número:  12349786

# %%
# Exercício 3 - Crie a classe Smartphone com 2 atributos, tamanho e interface e crie a classe MP3Player com os 
# atributos capacidade. A classe MP3player deve herdar os atributos da classe Smartphone.

class Smartphone():
    
    def __init__(self):
        print("Smartphone criado!")
    
    def Tamanho(self):
        print("Tamanho")
        
    def Interface(self):
        print("Interface")
    
class MP3Player(Smartphone):
    
    def __init__(self):
        Smartphone.__init__(self)
        print("MP3Player criado!")
        
    def Capacidade(self):
        print("Capacidade")

# %%
mp3_teste = MP3Player()
# Out:
# Smartphone criado!
# MP3Player criado!

# %%
mp3_teste.Capacidade()
# Out:
# Capacidade

# %%
mp3_teste.Interface()
# Out:
# Interface
