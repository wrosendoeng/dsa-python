# %%
for i in range(50,101,2):
    print(i)
# Out:
# 50
# 52
# 54
# 56
# 58
# 60
# 62
# 64
# 66
# 68
# 70
# 72
# 74
# 76
# 78
# 80
# 82
# 84
# 86
# 88
# 90
# 92
# 94
# 96
# 98
# 100

# %%
for i in range(3, 6):
    print(i)
# Out:
# 3
# 4
# 5

# %%
lista = ['morango', 'laranja', 'pera', 'banana', 'abacaxi', 'uva']
lista_tamanho = len(lista)

for i in range(0,lista_tamanho):
    print(lista[i])
# Out:
# morango
# laranja
# pera
# banana
# abacaxi
# uva

# %%
type(range(0,3))
# Out:
# range
