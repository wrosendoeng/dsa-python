# %%
def potencia(num):
    result = num ** 2
    return result

# %%
potencia(5)
# Out:
# 25

# %%
def potencia(num):
    return num**2

# %%
potencia(5)
# Out:
# 25

# %%
def potencia(num) : return num**2

# %%
potencia(5)
# Out:
# 25

# %%
par = lambda x: x%2 == 0

# %%
par(3)
# Out:
# False

# %%
potencia = lambda x: x ** 2

# %%
potencia(5)
# Out:
# 25

# %%
first = lambda s: s[0]

# %%
first([1,2,3,4])
# Out:
# 1

# %%
reverso = lambda s: s[::-1]

# %%
reverso('Python')
# Out:
# 'nohtyP'

# %%
addNum = lambda x,y: x+y

# %%
addNum(5,6)
# Out:
# 11

# %% [markdown]
# # FIM
