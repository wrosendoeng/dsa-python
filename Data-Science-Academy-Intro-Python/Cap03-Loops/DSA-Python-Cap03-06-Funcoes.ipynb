# %%
def primeiraFunc():
    print('Hello World')
    
primeiraFunc()
# Out:
# Hello World

# %%
def primeiraFunc(nome):
    print('Hello %s' %(nome))

primeiraFunc('Wallace')
# Out:
# Hello Wallace

# %%
def funcLeitura():
    for i in range(0,5):
        print("Numero " + str(i))

# %%
funcLeitura()
# Out:
# Numero 0
# Numero 1
# Numero 2
# Numero 3
# Numero 4

# %%
def addNum(firstnum,secondnum):
    print("primeiro número " + str(firstnum))
    print("segundo número " + str(secondnum))
    print("Soma: ",firstnum + secondnum)

# %%
addNum(1,2)
# Out:
# primeiro número 1
# segundo número 2
# Soma:  3

# %% [markdown]
# # Variáveis globais e locais:

# %%
var_global = 10

def multiply(num1, num2):
    var_global = num1 * num2
    print(var_global)

# %%
multiply(10,25)
# Out:
# 250

# %%
print(var_global)
# Out:
# 10

# %% [markdown]
# # Funções Built-in

# %%
abs(-56)
# Out:
# 56

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(2)
# Out:
# True

# %% [markdown]
# # Funções str, int, float

# %%
idade = int(input("Digite sua idade: "))
if idade > 13:
    print("Você pode acessar o Facebook")
# Out:
# Digite sua idade: 15
# Você pode acessar o Facebook

# %%
int("26")
# Out:
# 26

# %%
float(123)
# Out:
# 123.0

# %%
str(14)
# Out:
# '14'

# %%
len([23,24,45,46])
# Out:
# 4

# %%
array = ['a','b','c']

# %%
max(array)
# Out:
# 'c'

# %%
sum(array)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-568bbffb8c93> in <module>
# ----> 1 sum(array)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
import math

def numPrimo(num):
    
    if (num % 2) == 0 and num > 2:
        return "Este número não é primo"
    for i in range(3, int(math.sqrt(num)) +1, 2):
        if (num % i) == 0:
            return "Este número não é primo"
    return "Este número é primo"

# %%
numPrimo(541)
# Out:
# 'Este número é primo'

# %% [markdown]
# # Fazendo split de dados:

# %%
def split_string(text):
    return text.split(" ")

# %%
texto = "Esta funcao sera bastante importante para separar grandes volumes de dados."

# %%
split_string(texto)
# Out:
# ['Esta',
#  'funcao',
#  'sera',
#  'bastante',
#  'importante',
#  'para',
#  'separar',
#  'grandes',
#  'volumes',
#  'de',
#  'dados.']

# %%
caixa_baixa = "Este Texto Deveria Estar Todo em Minúsculo"

# %%
def lowercase(text):
    return text.lower()

# %%
lowercased_string = lowercase(caixa_baixa)

# %%
lowercased_string
# Out:
# 'este texto deveria estar todo em minúsculo'

# %%
def printVarInfo(arg1, *vartuple):
    print("O parâmetro passado foi: ", arg1)
    
    for item in vartuple:
        print("O parâmetro passado foi: ", item)
    return;

# %%
printVarInfo(10)
# Out:
# O parâmetro passado foi:  10

# %%
printVarInfo('Chocolate','Morango','Banana')
# Out:
# O parâmetro passado foi:  Chocolate
# O parâmetro passado foi:  Morango
# O parâmetro passado foi:  Banana
