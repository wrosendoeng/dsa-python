# %% [markdown]
# # Jogo da Forca

# %%
import random

# %%
arquivo = open("jogo-forca.txt","r")

# %%
board = [
    '''********************************* Hangman *********************************
 +-----+
 |     |
       |
       |
       |
       |
============''', '''
 +-----+
 |     |
 O     |
       |
       |
       |
============''', '''
 +-----+
 |     |
 O     |
 |     |
       |
       |
============''', '''
 +-----+
 |     |
 O     |
/|     |
       |
       |
============''', '''
 +-----+
 |     |
 O     |
/|\    |
       |
       |
============''', '''
 +-----+
 |     |
 O     |
/|\    |
/      |
       |
============''', '''
 +-----+
 |     |
 O     |
/|\    |
/ \    |
       |
============'''
]
