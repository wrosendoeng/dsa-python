# %%
seq = ['a','b','c']

# %%
enumerate(seq)

# %%
list(enumerate(seq))
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c')]

# %%
for indice, valor in enumerate(seq):
    print(indice,valor)
# Out:
# 0 a
# 1 b
# 2 c

# %%
for indice, valor in enumerate(seq):
    if indice >= 2:
        break
    else:
        print(valor)
# Out:
# a
# b

# %%
lista = ['Marketing','Tecnologia','Business']

# %%
list(enumerate(lista))
# Out:
# [(0, 'Marketing'), (1, 'Tecnologia'), (2, 'Business')]
